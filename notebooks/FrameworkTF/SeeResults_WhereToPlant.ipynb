# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import ipywidgets as widgets
import operator
import pandas as pd
from IPython import display
from iarchitect.trainer import Trainer
from iarchitect.common import create_policy_eval_video
from iarchitect.solutions import read_args,make_environment

p = Path.cwd().parents[1] / "iarchitect" / "solutions"
sols = [str(d.name) for d in p.iterdir() if not d.is_file()]
# Out:
# 2022-03-09 13:10:49.299372: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-09 13:10:49.299420: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
cbox = widgets.RadioButtons(
    placeholder="Choose Solution",
    options=sols,
    description='Choose Solution:',
    ensure_option=True,
    disabled=False
)
cbox
# Out:
# RadioButtons(description='Choose Solution:', options=('WindowEnvWhatPlantGrosReseau_discount0_2_dimension16_re…

# %%
assert cbox.value in sols
psols = p / cbox.value
results = []
results2 = []
for d in psols.iterdir():
    if d.is_file():
        if d.suffix==".png":
            num_res,date,num_step = d.stem.split("_")
            results.append((num_res,date,num_step ))
    if d.is_dir() and d.name[:min(len("policy"),len(d.name))]=="policy":
        date,num_step = d.name.split("_")
        date=date[len("policy"):]
        results2.append((date,num_step))
df = pd.DataFrame(results).sort_values(by=1,ascending=False)
df2 = pd.DataFrame(results2).sort_values(by=1,ascending=False)

cbox2 = widgets.Combobox(
    placeholder="Choose Iteration",
    options=list(df[2].values),
    description='Choose Step:',
    ensure_option=True,
    disabled=False
)
cbox2
# Out:
# Combobox(value='', description='Choose Step:', ensure_option=True, options=('1590', '1580', '1570', '1560', '1…

# %%
name = "_".join(df[df[2]==cbox2.value].values.flat)
suff = "_".join(df[df[2]==cbox2.value].iloc[0,1:])
policy_folder = "_".join(df2[df2[1]==cbox2.value].iloc[0,:])
display.Image(psols / f"{name}.png")

# %%
policy = Trainer.load_policy(str(psols),policy_folder)
# Out:
# /home/maxime/code/mcaox/iarchitect/iarchitect/solutions/WindowEnvWhatPlantGrosReseau_discount0_2_dimension16_resetTrue_maxspe1_str5/policy220308235353_1580
# 2022-03-09 13:11:00.975865: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-09 13:11:00.975920: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-09 13:11:00.975938: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ALS-358): /proc/driver/nvidia/version does not exist
# 2022-03-09 13:11:00.976119: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
args = read_args(psols)
env,tf_env = make_environment(args)
args
# Out:
# /home/maxime/code/mcaox/iarchitect/iarchitect/solutions/WindowEnvWhatPlantGrosReseau_discount0_2_dimension16_resetTrue_maxspe1_str5/args.json
# Namespace(dimension=16, discount=0.2, greedy_epsilon=0.1, max_species_reset=1, maximum_iterations=100000, name_env='windows_env_big_network', num_iterations_train=10, random_reset=True, sample_batch_size_experience=64, strategie=5, suff=None)

# %%
filename = f"{psols}/behaviour_step{cbox2.value}"
filename
# Out:
# '/home/maxime/code/mcaox/iarchitect/iarchitect/solutions/WindowEnvWhatPlantGrosReseau_discount0_2_dimension16_resetTrue_maxspe1_str5/behaviour_step1580'

# %%
create_policy_eval_video(tf_env,env,policy,filename,num_episodes=5,fps=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 create_policy_eval_video(tf_env,env,policy,filename,num_episodes=5,fps=5)
#
# File ~/code/mcaox/iarchitect/iarchitect/common/__init__.py:40, in create_policy_eval_video(tf_env, py_env, policy, filename, num_episodes, fps, each_n_action, embed)
#      38 time_step = tf_env.step(action_step.action)
#      39 if iaction % each_n_action ==0:
# ---> 40     img = py_env.render(mode="rgb_array")
#      41     images.append(Image.fromarray(img))
#      42     plotted = True
#
# File ~/code/mcaox/iarchitect/iarchitect/envs/windows_env.py:337, in WindowEnv.render(self, mode)
#     335     return "\n".join(grid+last+quotas +taux +totaux)
#     336 else:
# --> 337     return np.array(self.render_image())
#
# File ~/code/mcaox/iarchitect/iarchitect/envs/windows_env.py:329, in WindowEnv.render_image(self)
#     327 n = (len(last)+len(quotas)+len(taux)+len(totaux))
#     328 fnt_sizes[-n:] = [int(40/3)]*n
# --> 329 im = image_from_text(texts,fnt_sizes,max_size=546)
#     330 return im
#
# File ~/code/mcaox/iarchitect/iarchitect/render/__init__.py:51, in image_from_text(texts, size_fnts, path_font, max_size)
#      49     fnt = ImageFont.truetype(str(path_font), size_fnt)
#      50     with Pilmoji(im) as pilmoj:
# ---> 51         pilmoj.text((size_fnt//2,pos), text, font=fnt, fill=(0, 0, 0), embedded_color=True)
#      52     pos += len(text.splitlines())*size_fnt
#      53 # if max_size is not None:
#      54 #     if max(im.size)>max_size:
#      55 #         ratio = max_size/max(im.size)
#    (...)
#      58 #                         ))
#      59 #         print(im.size)
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/pilmoji/core.py:299, in Pilmoji.text(self, xy, text, fill, font, anchor, spacing, align, direction, features, language, stroke_width, stroke_fill, embedded_color, emoji_scale_factor, emoji_position_offset, *args, **kwargs)
#     297 stream = None
#     298 if node.type is NodeType.emoji:
# --> 299     stream = self._get_emoji(content)
#     301 elif self._render_discord_emoji and node.type is NodeType.discord_emoji:
#     302     stream = self._get_discord_emoji(content)
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/pilmoji/core.py:154, in Pilmoji._get_emoji(self, emoji)
#     151     entry.seek(0)
#     152     return entry
# --> 154 if stream := self.source.get_emoji(emoji):
#     155     if self._cache:
#     156         self._emoji_cache[emoji] = stream
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/pilmoji/source.py:166, in EmojiCDNSource.get_emoji(self, emoji)
#     163 _to_catch = HTTPError if not _has_requests else requests.HTTPError
#     165 try:
# --> 166     return BytesIO(self.request(url))
#     167 except _to_catch:
#     168     pass
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/pilmoji/source.py:116, in HTTPBasedSource.request(self, url)
#      96 """Makes a GET request to the given URL.
#      97
#      98 If the `requests` library is installed, it will be used.
#    (...)
#     113     There was an error requesting from the URL.
#     114 """
#     115 if _has_requests:
# --> 116     with self._requests_session.get(url, **self.REQUEST_KWARGS) as response:
#     117         if response.ok:
#     118             return response.content
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/requests/sessions.py:542, in Session.get(self, url, **kwargs)
#     534 r"""Sends a GET request. Returns :class:`Response` object.
#     535
#     536 :param url: URL for the new :class:`Request` object.
#     537 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     538 :rtype: requests.Response
#     539 """
#     541 kwargs.setdefault('allow_redirects', True)
# --> 542 return self.request('GET', url, **kwargs)
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/iarchitect/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.8.12/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import numpy as np
from IPython.display import display
env.reset()
for i in range(16):
    env.step(np.array(i))
    display(env.render_image())
# Out:
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41FD0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41E50>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C415E0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41C10>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41C40>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C414C0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C418B0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41940>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41A60>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41C40>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41190>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41E50>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41FD0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41CA0>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C41D30>
# <PIL.Image.Image image mode=RGBA size=336x304 at 0x7FB4F8C411F0>

# %%
import numpy as np
from IPython.display import display
time_step = tf_env.reset()
while not time_step.is_last():
    action_step = policy.action(time_step)
    time_step = tf_env.step(action_step.action)
    display(env.render_image())
# Out:
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F8141408AC0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F81A31EFCA0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F8141408070>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B5DFCD0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F8141408CA0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544970>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F8141408AC0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B5DFCD0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544850>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544970>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B5449D0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544970>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544460>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F81A31EFCA0>
# <PIL.Image.Image image mode=RGBA size=288x288 at 0x7F819B544970>
# <PIL.Image.Image image mode=RGBA size=304x288 at 0x7F819B544460>
